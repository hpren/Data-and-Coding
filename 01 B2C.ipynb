# %% [markdown]
# SASB Industry Consumer facing

# %%
import pandas as pd
import numpy as np

# %%
supply2024 = pd.read_excel(r"C:\Users\huipingr\Dropbox\4_SASB\Data and Coding\SUPPLY-USE\Use_Summary_2024.xlsx", sheet_name="Supply2024-coding")
supply2024 = supply2024.set_index('IO code')
supply2024.head()
# Out:
#                             Commodities/Industries     111CA     113FF  \
# IO code
# 111CA                                        Farms  0.982922  0.000446
# 113FF    Forestry, fishing, and related activities  0.012311  0.983872
# 211                         Oil and gas extraction  0.000000  0.000000
# 212                     Mining, except oil and gas  0.000000  0.000000
# 213                  Support activities for mining  0.000000  0.000000
#
#               211       212       213        22   23  321       327  ...  \
# IO code                                                              ...
# 111CA    0.000000  0.000000  0.000000  0.000000  0.0  0.0  0.000000  ...
# 113FF    0.000000  0.000000  0.000000  0.000000  0.0  0.0  0.000000  ...
# 211      0.851246  0.000000  0.003273  0.000215  0.0  0.0  0.000000  ...
# 212      0.000125  0.772673  0.000000  0.000000  0.0  0.0  0.004335  ...
# 213      0.040233  0.071463  0.923846  0.000000  0.0  0.0  0.000000  ...
#
# ...
